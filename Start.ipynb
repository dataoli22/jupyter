# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
file_path = r'C:\Users\olich\Downloads\datasets\Print Adex Dump FY 22 & 23.xlsx'  # Update with your file path
df = pd.read_excel(file_path)
df.head()
# Out:
#                 PERIOD MEDIUM SUPER CATEGORY               ADVERTISER  \
# 0  Apr 2021 - Jun 2021  PRINT    Agriculture          Aastha Organics
# 1  Apr 2021 - Jun 2021  PRINT    Agriculture  Abhimanyu Seeds Pvt Ltd
# 2  Apr 2021 - Jun 2021  PRINT    Agriculture  Abhimanyu Seeds Pvt Ltd
# 3  Apr 2021 - Jun 2021  PRINT    Agriculture  Abhimanyu Seeds Pvt Ltd
# 4  Apr 2021 - Jun 2021  PRINT    Agriculture  Abhimanyu Seeds Pvt Ltd
#
#                 PRODUCT PUB NATURE          PUBLICATION PUB LANGUAGE  \
# 0       Aastha Organics  Newspaper  Dainik Jagran-jammu        Hindi
# 1     Abhimanyu Abhi-09  Newspaper    Dainik Jagran-jhn        Hindi
# 2    Abhimanyu Kanhaiya  Newspaper    Dainik Jagran-jhn        Hindi
# 3  Abhimanyu Magic Gold  Newspaper    Dainik Jagran-jhn        Hindi
# 4    Abhimanyu Sampanna  Newspaper    Dainik Jagran-jhn        Hindi
#
#              STATE  FREQUENCY  VOL_CC  VOL_SQCM  TAM COST  BASE_COST
# ...
